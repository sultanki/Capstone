# %% [markdown]
# <a href="https://colab.research.google.com/github/sultanki/Capstone/blob/New-Branch/FMR_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = gc.open_by_url('https://docs.google.com/spreadsheets/d/17E1acHMRKL7-2-J_pcqYDN2R7CMwS0AxQGbaCngLQqU/edit?usp=sharing')

# %%
sheet = url.worksheet('Sheet1')

# %%
data = sheet.get_all_values()

# %%
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
df
# Out:
# 0              County 0 Bedrooms 1 Bedrooms 2 Bedrooms 3 Bedrooms 4 Bedrooms
# 1        Adams County  $1,769.00  $1,956.00  $2,408.00  $3,279.00  $3,732.00
# 2      Alamosa County    $972.00    $989.00  $1,268.00  $1,631.00  $2,172.00
# 3     Arapahoe County  $1,769.00  $1,956.00  $2,408.00  $3,279.00  $3,732.00
# 4    Archuleta County  $1,169.00  $1,176.00  $1,550.00  $1,968.00  $2,684.00
# 5         Baca County    $930.00    $936.00  $1,101.00  $1,575.00  $1,907.00
# ..                ...        ...        ...        ...        ...        ...
# 60      Summit County  $1,800.00  $1,982.00  $2,411.00  $3,267.00  $3,795.00
# 61      Teller County  $1,142.00  $1,313.00  $1,730.00  $2,475.00  $2,813.00
# 62  Washington County  $1,049.00  $1,073.00  $1,223.00  $1,521.00  $1,661.00
# 63        Weld County  $1,241.00  $1,406.00  $1,776.00  $2,541.00  $2,982.00
# 64        Yuma County    $944.00    $951.00  $1,253.00  $1,698.00  $1,698.00
#
# [64 rows x 6 columns]

# %%
# Unpivot the dataframe

df = df. melt(id_vars='County', var_name='Bedrooms', value_name='Amounts')

# %%
df.head(20)
# Out:
#                 County    Bedrooms    Amounts
# 0         Adams County  0 Bedrooms  $1,769.00
# 1       Alamosa County  0 Bedrooms    $972.00
# 2      Arapahoe County  0 Bedrooms  $1,769.00
# 3     Archuleta County  0 Bedrooms  $1,169.00
# 4          Baca County  0 Bedrooms    $930.00
# 5          Bent County  0 Bedrooms    $978.00
# 6       Boulder County  0 Bedrooms  $1,919.00
# 7    Broomfield County  0 Bedrooms  $1,769.00
# 8       Chaffee County  0 Bedrooms    $902.00
# 9      Cheyenne County  0 Bedrooms    $830.00
# 10  Clear Creek County  0 Bedrooms  $1,769.00
# 11      Conejos County  0 Bedrooms    $896.00
# 12     Costilla County  0 Bedrooms    $944.00
# 13      Crowley County  0 Bedrooms  $1,019.00
# 14       Custer County  0 Bedrooms    $978.00
# 15        Delta County  0 Bedrooms  $1,109.00
# 16       Denver County  0 Bedrooms  $1,769.00
# 17      Dolores County  0 Bedrooms    $915.00
# 18      Douglas County  0 Bedrooms  $1,769.00
# ...

# %%
 df.sort_values(by=['County','Bedrooms'], inplace=True)
 df.head(10)
# Out:
#              County    Bedrooms    Amounts
# 0      Adams County  0 Bedrooms  $1,769.00
# 64     Adams County  1 Bedrooms  $1,956.00
# 128    Adams County  2 Bedrooms  $2,408.00
# 192    Adams County  3 Bedrooms  $3,279.00
# 256    Adams County  4 Bedrooms  $3,732.00
# 1    Alamosa County  0 Bedrooms    $972.00
# 65   Alamosa County  1 Bedrooms    $989.00
# 129  Alamosa County  2 Bedrooms  $1,268.00
# 193  Alamosa County  3 Bedrooms  $1,631.00
# 257  Alamosa County  4 Bedrooms  $2,172.00

# %%
for item in df.index:
 # counties_allowed = ['Adams County','Arapahoe County']
 # for county in counties_allowed:
    note = """Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021), \nverified FMR for {} bedroom(s) in {} County is {}.\n""".format(
    df['County'][item], df['Bedrooms'][item], df['Amounts'][item])  
    print(note)
   
      
      # df['County'][item], df['Bedrooms'][item], df['Amounts'][item])
# Out:
# Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021),
# verified FMR for Adams County bedroom(s) in 0 Bedrooms County is $1,769.00.
#
# Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021),
# verified FMR for Adams County bedroom(s) in 1 Bedrooms County is $1,956.00.
#
# Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021),
# verified FMR for Adams County bedroom(s) in 2 Bedrooms County is $2,408.00.
#
# Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021),
# verified FMR for Adams County bedroom(s) in 3 Bedrooms County is $3,279.00.
#
# Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021),
# verified FMR for Adams County bedroom(s) in 4 Bedrooms County is $3,732.00.
#
# Per the guidelines for 2021 adjusted: 150% of FMR (Effective 3/1/2021 ‐ 9/30/2021),
# verified FMR for Alamosa County bedroom(s) in 0 Bedrooms County is $972.00.
#
# ...
